# %%
# %load_ext autoreload
# %autoreload 2
# this only works on startup!
from jax import config
config.update("jax_enable_x64", True)

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = '3'
from encoding_information.gpu_utils import limit_gpu_memory_growth
limit_gpu_memory_growth()

from cleanplots import *
from tqdm import tqdm
from signal_utils_1D import *
from plot_utils_1D import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
N_objects = 2000
noise_sigma = 1e-3

erasure_mask = onp.ones(NUM_NYQUIST_SAMPLES)
erasure_mask = np.array(erasure_mask, dtype=bool)
sampling_indices = (1, 2)

num_deltas_list = 2 ** np.arange(0, 10)
mutual_informations = []
for num_deltas in num_deltas_list:
    objects_fn = lambda : np.array([sample_amplitude_object('delta', num_deltas=num_deltas) * num_deltas for i in range(N_objects)])

    initial_kernel, initial_params, optimized_params, objects, initial_mi, optimized_mi = optimize_PSF_and_estimate_mi(objects_fn, noise_sigma, erasure_mask)
    
    mutual_informations.append(optimized_mi)
# Out:
# initial loss -3.945782964360733
# initial loss -4.619002270350876
# initial loss -5.020343913624291
# initial loss -5.264460073648481
# initial loss -5.790384801710966
# initial loss -6.171543241760202
# initial loss -6.644043534816957
# initial loss -7.393350738887888
# 4999: -9.1990820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> for num_deltas in num_deltas_list:
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     objects_fn = lambda : np.array([sample_amplitude_object('delta', num_deltas=num_deltas) * num_deltas for i in range(N_objects)])
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     initial_kernel, initial_params, optimized_params, objects, initial_mi, optimized_mi = optimize_PSF_and_estimate_mi(objects_fn, noise_sigma, erasure_mask)
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     mutual_informations.append(optimized_mi)
#
# File /2tb_nvme/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/signal_utils_1D.py:43, in optimize_PSF_and_estimate_mi(objects_fn, noise_sigma, erasure_mask, initial_kernel, learning_rate, learning_rate_decay, verbose, loss_improvement_patience, max_epochs, num_nyquist_samples, nyquist_sample_output)
#      37 loss_fn = make_convolutional_forward_model_with_mi_loss_and_erasure(
#      38     objects, erasure_mask, noise_sigma=noise_sigma, num_nyquist_samples=num_nyquist_samples, nyquist_sample_output=nyquist_sample_output)
#      39 optimized_params = run_optimzation(loss_fn, lambda x : real_imag_bandlimit_energy_norm_prox_fn(x, num_nyquist_samples=num_nyquist_samples),
#      40                         initial_params, learning_rate=learning_rate, learning_rate_decay=learning_rate_decay, verbose=verbose,
#      41                         loss_improvement_patience=loss_improvement_patience, max_epochs=max_epochs,
#      42                         key=jax.random.PRNGKey(onp.random.randint(100000)))
# ---> 43 test_objects = objects_fn()
#      44 optimized_mi = -make_convolutional_forward_model_with_mi_loss_and_erasure(test_objects, erasure_mask, noise_sigma=noise_sigma,
#      45                                                                           num_nyquist_samples=num_nyquist_samples, nyquist_sample_output=nyquist_sample_output
#      46                                                                           )(optimized_params, jax.random.PRNGKey(0))
#      47 initial_mi = -make_convolutional_forward_model_with_mi_loss_and_erasure(test_objects, erasure_mask, noise_sigma=noise_sigma,
#      48                                                                         num_nyquist_samples=num_nyquist_samples, nyquist_sample_output=nyquist_sample_output
#      49                                                                         )(initial_params, jax.random.PRNGKey(0))
#
# /home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> mutual_informations = []
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> for num_deltas in num_deltas_list:
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     objects_fn = lambda : np.array([sample_amplitude_object('delta', num_deltas=num_deltas) * num_deltas for i in range(N_objects)])
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     initial_kernel, initial_params, optimized_params, objects, initial_mi, optimized_mi = optimize_PSF_and_estimate_mi(objects_fn, noise_sigma, erasure_mask)
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     mutual_informations.append(optimized_mi)
#
# /home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> mutual_informations = []
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> for num_deltas in num_deltas_list:
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     objects_fn = lambda : np.array([sample_amplitude_object('delta', num_deltas=num_deltas) * num_deltas for i in range(N_objects)])
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     initial_kernel, initial_params, optimized_params, objects, initial_mi, optimized_mi = optimize_PSF_and_estimate_mi(objects_fn, noise_sigma, erasure_mask)
#      <a href='vscode-notebook-cell://ssh-remote%2Bwaller-fuoco.eecs.berkeley.edu/home/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/max_information_with_more_deltas.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     mutual_informations.append(optimized_mi)
#
# File /2tb_nvme/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/signal_utils_1D.py:110, in sample_amplitude_object(type, seed, object_size, num_deltas, sin_freq_range, gaussian_mixture_position, num_mixture_components, gaussian_mixture_seed)
#     108     delta_function = onp.zeros(object_size)
#     109     for i in range(num_deltas):
# --> 110         delta_function[get_random_position()] += 1 / num_deltas
#     111     return delta_function
#     112 elif type == 'random_amplitude_delta':
#
# File /2tb_nvme/hpinkard_waller/GitRepos/EncodingInformation/1d_simulations/signal_utils_1D.py:100, in sample_amplitude_object.<locals>.get_random_position()
#      98 def get_random_position():
#      99     if not gaussian_mixture_position:
# --> 100         return onp.random.randint(object_size)
#     101     else:
#     102         component = onp.random.choice(num_mixture_components, p=weights)
#
# KeyboardInterrupt:

# %%
len(mutual_informations)
# Out:
# 7

# %%
# plot num_deltas vs mutual information
plt.figure(figsize=(5, 5))
plt.plot(num_deltas_list[:len(mutual_informations)], mutual_informations, 'o-')
plt.xlabel('num deltas')
plt.ylabel('mutual information')
# Out:
# Text(0, 0.5, 'mutual information')
