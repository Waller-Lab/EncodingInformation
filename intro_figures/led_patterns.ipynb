# %%
from bsccm.led_array_calibration import plot_led_pattern
from cleanplots import *

fig, ax = plt.subplots(3, 1, figsize=(4, 12), sharex=True, sharey=True)

for i, channel in enumerate(['Brightfield', 'DPC_Left', 'LED119']):
    plot_led_pattern(channel_name=channel, ax=ax[i], legend=i==0)

fig.savefig('/home/hpinkard_waller/figures/intro_slides/led_pattern.pdf', transparent=True)
